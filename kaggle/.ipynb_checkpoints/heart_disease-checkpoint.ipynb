# %% [markdown]
# ### Analysing heart disease data from kaggle

# %%
import pyforest

# %% [markdown]
# #### Load dataset

# %%
heart_disease_df = pd.read_csv('data/Heart_disease_details.csv')
heart_disease_df.head()
# Out:
#                Name  ...                                   Treatment
# 0          Jane Doe  ...  Angioplasty,Coronary artery bypass surgery
# 1      Mark Johnson  ...  Angioplasty,Coronary artery bypass surgery
# 2       Emily Davis  ...  Angioplasty,Coronary artery bypass surgery
# 3  William Thompson  ...  Angioplasty,Coronary artery bypass surgery
# 4    Ashley Johnson  ...  Angioplasty,Coronary artery bypass surgery
#
# [5 rows x 49 columns]

# %% [markdown]
# #### Statistical summary

# %%
# heart_disease_df.describe()

# %% [markdown]
# #### Techincal summary
# ###### No field with null value

# %%
# heart_disease_df.info()

# %% [markdown]
# #### Visualisation of data against age

# %%
# heart_disease_df['age'] = heart_disease_df['Age'].astype(int)
# heart_disease_df[["Chest pain", "Drug use"]].plot(x='age', subplots=True, layout=(2,2), figsize=(10,10))
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Documents/dummiesProjects/DS-Bootcamp/env/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/Documents/dummiesProjects/DS-Bootcamp/env/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/Documents/dummiesProjects/DS-Bootcamp/env/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'age'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[36], line 2
#       1 heart_disease_df['age'] = heart_disease_df['Age'].astype(int)
# ----> 2 heart_disease_df[["Chest pain", "Drug use"]].plot(x='age', subplots=True, layout=(2,2), figsize=(10,10))
#       3 plt.show()
#
# File ~/Documents/dummiesProjects/DS-Bootcamp/env/lib/python3.10/site-packages/pandas/plotting/_core.py:965, in PlotAccessor.__call__(self, *args, **kwargs)
#     963 if is_integer(x) and not data.columns.holds_integer():
#     964     x = data_cols[x]
# --> 965 elif not isinstance(data[x], ABCSeries):
#     966     raise ValueError("x must be a label or position")
#     967 data = data.set_index(x)
#
# File ~/Documents/dummiesProjects/DS-Bootcamp/env/lib/python3.10/site-packages/pandas/core/frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~/Documents/dummiesProjects/DS-Bootcamp/env/lib/python3.10/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'age'
